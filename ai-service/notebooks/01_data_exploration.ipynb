# %% [markdown]
# # Satellite Data Exploration Notebook
# --------------------------------------
# Explores 6-band Sentinel-2 optical GeoTIFFs, 3-channel Sentinel-1 SAR GeoTIFFs, and weather time-series.

# %%
import rasterio
import pandas as pd
import numpy as np

manifest = pd.read_csv('../manifests/train.csv')
print('Dataset manifest loaded:', len(manifest), 'samples')
print(manifest.head())
