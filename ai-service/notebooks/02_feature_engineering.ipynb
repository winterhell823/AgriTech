# %% [markdown]
# # Geospatial Feature Engineering Notebook
# -----------------------------------------
# Calculates NDVI, NDWI, EVI, SAVI spectral indices and SAR backscatter ratios.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from app.features.optical_features import calculate_ndvi, calculate_ndwi
import numpy as np

nir = np.full((512, 512), 0.7, dtype=np.float32)
red = np.full((512, 512), 0.1, dtype=np.float32)
ndvi = calculate_ndvi(nir, red)
print('Calculated mean NDVI:', np.mean(ndvi))
